# %% [markdown]
# ## Importing Necessary Modules

# %%
#import necessary libraries

from googleapiclient.discovery import build
import pandas as pd

# %% [markdown]
# ## Extracting Channel Details

# %%
api_key = 'AIzaSyB8EsqsdsIcrGIU4_U-Q9YrPhKUjCiwHFQ'

channel_ids = ['UCnka1A32ye14_yCvXIWTOuQ', #Doakl
               'UCgiZJgpmzcbCW30ywLHVPkQ', #SisiYemmie
               'UCaUfud8pU8ztkI45gxzPjzQ', #Dimma
               'UC8p_y3iHPe-n3zRfXK2czWA', #TayoAina
               'UCuugO5O_RaGMQQ7EU32RuNQ', #Dyna
               'UCjlMIFG7iqaQMN1FXEkRCEA', #Nelo
               'UC4RXRX52KOJCJg_O0QP95iw', #Abi
               'UCf4mp5293pg16Bd7vRC4v1g', #Tolulope
               'UCfzuuaIc3cJBH9NM-GObAPA', #AlmaNgur
               'UCz_RS3QUnU9cb9LCWGTtgtg', #OloriEsho
               'UCFydN_LFZnwtKU88PjQt6kA', #Omabelle
               'UCHpJ56HrMgu1qh14F2i1MlQ', #BemiBadmus
               'UCiI6AwM3EPSToQQw4JNMajQ', #MercyGono
               'UCnlZeo3nqRG_h7XgsjooTbQ', #Yeychi
               'UCj2LgtXaRKnhQoC-NGXrOZQ', #EzinneZara
               'UCj1ltGgktC2EofJQehlx8Jg', #TobiAdekeye
               'UC7cs8q-gJRlGwj4A8OmCmXg', #AlextheAnalyst
               'UCMT3W4oP94ZxbY9jPu8DQZg', #AyshaHarun
               'UCVYa_MSgARc9cL75RPjUu_w', #OTlovetrain
               'UC2UXDak6o7rBm23k3Vv5dww', #TinaHuang
               'UCkw4JCwteGrDHIsyIIKo4tQ', #Edureka
               'UCWv7vMbMWH4-V0ZXdmDpPBA', #ProgrammingwithMosh
               'UC4SWY-aE043Gl2gl4YzvCIQ', #ChinyereAbang
               'UCgSStdl6pBmikakcUngo_8Q', #OlusolaLove
               'UCZC2LMeHTfAq8GOj4MEPHFg', #onyeka
               'UCDQuFMpWGvgQ3ZJisoGNgjg', #adaeze
               'UCnz-ZXXER4jOvuED5trXfEA', #TechTFQ
               'UCi0jBGKMYsoefrRSjyUADag', #TrumpExcel
               'UCiYjpuUaSfkvdZkmtDU7JRw', #myonlinetraininghub
               'UC39zVnTMX-qJEfIRJSwuNhg', #TomikeAdeoye
               ]

api_service_name = 'youtube'
api_version = 'v3'

#youtube = googleapiclient.discovery.build(api_service_name, api_version, credentials=credentials)
    
youtube = build('youtube', 'v3', developerKey= api_key )

# %% [markdown]
# ##  Channel Statistics

# %%
def get_channel_stats(youtube,channel_ids):
    youtube_data = []
    
    request = youtube.channels().list(
                part="snippet,contentDetails,statistics", id=','.join(channel_ids)) #using join() method to make the channel_ids which is a list to join them into a string. 
    
    response = request.execute()
    
   
    
    for i in range(len(response['items'])):
        
        snippet = response['items'][i]['snippet']
        
        statistics = response['items'][i]['statistics']
        
        data = dict(Channel_name = snippet.get('title', 'N/A'),
                    #Description =snippet.get('description','N/A'),
                    ChannelUrl = snippet.get('customUrl','N/A'),
                    PublishedDate = snippet.get('publishedAt','N/A'),
                    Country = snippet.get('country','N/A'),
                    SubscriberCount =  statistics.get('subscriberCount','N/A'), 
                    Views = statistics.get('viewCount','N/A'),
                    VideoCount = statistics.get('videoCount','N/A')
                   )
        
        youtube_data.append(data)
    
    return youtube_data

# %%
channelInfo = get_channel_stats(youtube,channel_ids)

# %%
Channel_df = pd.DataFrame(channelInfo)
Channel_df
# Out:
#                 Channel_name           ChannelUrl  \
# 0         Tolulope Solutions    tolulopesolutions
# 1           Alex The Analyst       alextheanalyst
# 2                Bemi Badmus                bemia
# 3                   edureka!            edurekain
# 4               Dyna Ekwueme          dynaekwueme
# 5             Chinyere Abang        chinyereabang
# 6             Adaeze's Space         adaezesspace
# 7               Tobi Adekeye          tobiadekeye
# 8              Tomike Adeoye         tomikeadeoye
# 9                Ezinne Zara           ezinnezara
# 10                Nelo Okeke            nelookeke
# 11                   techTFQ              techtfq
# 12              Olusola Love                  N/A
# 13        Mercy Gono BSN, RN                  N/A
# 14            Onyeka Asamaka        onyekaasamaka
# 15                 IAMYEYCHI            iamyeychi
# 16                TrumpExcel           trumpexcel
# 17                Dimma Umeh            dimmaumeh
# 18                Tina Huang           tinahuang1
# 19       MyOnlineTrainingHub  myonlinetraininghub
# 20              Abiandfamily         abiandfamily
# 21  Diary of a KITCHEN LOVER                  N/A
# 22         The OT Love Train       theotlovetrain
# 23               Aysha Harun           ayshaharun
# 24                 Tayo Aina        tayoainafilms
# 25              SisiYemmieTV         sisiyemmietv
# 26                 Alma Ngur             almangur
# 27                Olori Esho            oloriesho
# 28     Programming with Mosh  programmingwithmosh
# 29                OmabelleTV           omabelletv
#
#                   PublishedDate Country SubscriberCount      Views VideoCount
# 0          2017-07-07T16:28:13Z      CA          108000   18783264        313
# 1   2020-01-08T05:04:24.970712Z      US          234000    9260213        148
# 2          2011-09-27T04:20:28Z      NG           12200    1094738        334
# 3          2012-06-29T06:12:26Z      IN         3380000  315061452       6709
# 4          2017-02-16T15:25:25Z      US          113000   17604216        393
# 5          2013-12-18T18:31:33Z      US           41600    7598865        466
# 6          2017-11-09T17:28:43Z      NG           42700    6611094        391
# 7          2014-09-13T17:24:39Z      CA           26200    1370186         78
# 8          2014-02-09T07:53:59Z      US          105000   10314143         89
# 9          2015-06-16T06:22:58Z      NG           48500    1712837         61
# 10         2011-07-22T10:24:29Z      NG           89600   15610557        607
# 11  2020-06-13T05:20:37.182391Z      MY           82600    3772878         61
# 12         2011-10-31T12:52:42Z      CA           23600    1165375         76
# 13         2016-09-25T15:28:30Z      US         1580000  113690119        405
# 14         2015-11-01T17:07:39Z      CA           35100    1735417        120
# 15         2015-01-05T14:09:19Z      NG           12600     720415        192
# 16         2013-12-22T12:29:35Z     N/A          219000   27342159        382
# 17         2012-01-21T18:40:21Z      NG          448000   33830294        361
# 18         2013-08-28T18:05:17Z      US          342000   13017870        101
# 19         2010-04-11T13:56:56Z     N/A          435000   25679574        194
# 20         2018-10-08T19:24:01Z      CA           51500   16085446        855
# 21         2014-04-06T18:52:26Z      NG           47600    1325793        220
# 22         2017-04-05T19:05:23Z      CA            9260     608935        116
# 23         2011-06-13T00:35:14Z      US          482000   34406627        610
# 24         2015-04-05T11:12:56Z      NG          408000   38208299        309
# 25         2011-11-17T20:38:34Z      NG          771000   79185802        988
# 26         2013-06-03T12:29:18Z      NG           21600    4085121        426
# 27   2020-01-13T13:45:48.25651Z      US           25100    3180542        421
# 28         2014-10-07T00:40:53Z      AU         2550000  121758632        170
# 29         2012-04-26T18:14:36Z      US          558000   67804178        525

# %%
Channel_df.dtypes
# Out:
# Channel_name       object
# ChannelUrl         object
# PublishedDate      object
# Country            object
# SubscriberCount    object
# Views              object
# VideoCount         object
# dtype: object

# %%
Channel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Channel_name     30 non-null     object
#  1   ChannelUrl       30 non-null     object
#  2   PublishedDate    30 non-null     object
#  3   Country          30 non-null     object
#  4   SubscriberCount  30 non-null     object
#  5   Views            30 non-null     object
#  6   VideoCount       30 non-null     object
# dtypes: object(7)
# memory usage: 1.8+ KB

# %% [markdown]
# ## Exporting DataFrame to CSV

# %%
Channel_df.to_csv('youtube.csv', index=False)

# %%
data_csv = pd.read_csv('youtube.csv')
data_csv
# Out:
#                 Channel_name           ChannelUrl  \
# 0         Tolulope Solutions    tolulopesolutions
# 1           Alex The Analyst       alextheanalyst
# 2                Bemi Badmus                bemia
# 3                   edureka!            edurekain
# 4               Dyna Ekwueme          dynaekwueme
# 5             Chinyere Abang        chinyereabang
# 6             Adaeze's Space         adaezesspace
# 7               Tobi Adekeye          tobiadekeye
# 8              Tomike Adeoye         tomikeadeoye
# 9                Ezinne Zara           ezinnezara
# 10                Nelo Okeke            nelookeke
# 11                   techTFQ              techtfq
# 12              Olusola Love                  NaN
# 13        Mercy Gono BSN, RN                  NaN
# 14            Onyeka Asamaka        onyekaasamaka
# 15                 IAMYEYCHI            iamyeychi
# 16                TrumpExcel           trumpexcel
# 17                Dimma Umeh            dimmaumeh
# 18                Tina Huang           tinahuang1
# 19       MyOnlineTrainingHub  myonlinetraininghub
# 20              Abiandfamily         abiandfamily
# 21  Diary of a KITCHEN LOVER                  NaN
# 22         The OT Love Train       theotlovetrain
# 23               Aysha Harun           ayshaharun
# 24                 Tayo Aina        tayoainafilms
# 25              SisiYemmieTV         sisiyemmietv
# 26                 Alma Ngur             almangur
# 27                Olori Esho            oloriesho
# 28     Programming with Mosh  programmingwithmosh
# 29                OmabelleTV           omabelletv
#
#                   PublishedDate Country  SubscriberCount      Views  \
# 0          2017-07-07T16:28:13Z      CA           108000   18783264
# 1   2020-01-08T05:04:24.970712Z      US           234000    9260213
# 2          2011-09-27T04:20:28Z      NG            12200    1094738
# 3          2012-06-29T06:12:26Z      IN          3380000  315061452
# 4          2017-02-16T15:25:25Z      US           113000   17604216
# 5          2013-12-18T18:31:33Z      US            41600    7598865
# 6          2017-11-09T17:28:43Z      NG            42700    6611094
# 7          2014-09-13T17:24:39Z      CA            26200    1370186
# 8          2014-02-09T07:53:59Z      US           105000   10314143
# 9          2015-06-16T06:22:58Z      NG            48500    1712837
# 10         2011-07-22T10:24:29Z      NG            89600   15610557
# 11  2020-06-13T05:20:37.182391Z      MY            82600    3772878
# 12         2011-10-31T12:52:42Z      CA            23600    1165375
# 13         2016-09-25T15:28:30Z      US          1580000  113690119
# 14         2015-11-01T17:07:39Z      CA            35100    1735417
# 15         2015-01-05T14:09:19Z      NG            12600     720415
# 16         2013-12-22T12:29:35Z     NaN           219000   27342159
# 17         2012-01-21T18:40:21Z      NG           448000   33830294
# 18         2013-08-28T18:05:17Z      US           342000   13017870
# 19         2010-04-11T13:56:56Z     NaN           435000   25679574
# 20         2018-10-08T19:24:01Z      CA            51500   16085446
# 21         2014-04-06T18:52:26Z      NG            47600    1325793
# 22         2017-04-05T19:05:23Z      CA             9260     608935
# 23         2011-06-13T00:35:14Z      US           482000   34406627
# 24         2015-04-05T11:12:56Z      NG           408000   38208299
# 25         2011-11-17T20:38:34Z      NG           771000   79185802
# 26         2013-06-03T12:29:18Z      NG            21600    4085121
# 27   2020-01-13T13:45:48.25651Z      US            25100    3180542
# 28         2014-10-07T00:40:53Z      AU          2550000  121758632
# 29         2012-04-26T18:14:36Z      US           558000   67804178
#
#     VideoCount
# 0          313
# 1          148
# 2          334
# 3         6709
# 4          393
# 5          466
# 6          391
# 7           78
# 8           89
# 9           61
# 10         607
# 11          61
# 12          76
# 13         405
# 14         120
# 15         192
# 16         382
# 17         361
# 18         101
# 19         194
# 20         855
# 21         220
# 22         116
# 23         610
# 24         309
# 25         988
# 26         426
# 27         421
# 28         170
# 29         525

# %% [markdown]
# ## Exporting DataFrame to Excel

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\home\anaconda3\envs\ma-env\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\home\anaconda3\envs\ma-env\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
Channel_df.to_excel('excelsample.xlsx')

# %%
pd.read_excel('excelsample.xlsx',index_col=0)
# Out:
#                 Channel_name           ChannelUrl  \
# 0         Tolulope Solutions    tolulopesolutions
# 1           Alex The Analyst       alextheanalyst
# 2                Bemi Badmus                bemia
# 3                   edureka!            edurekain
# 4               Dyna Ekwueme          dynaekwueme
# 5             Chinyere Abang        chinyereabang
# 6             Adaeze's Space         adaezesspace
# 7               Tobi Adekeye          tobiadekeye
# 8              Tomike Adeoye         tomikeadeoye
# 9                Ezinne Zara           ezinnezara
# 10                Nelo Okeke            nelookeke
# 11                   techTFQ              techtfq
# 12              Olusola Love                  NaN
